# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from scratch
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
import os
root_dir = os.path.dirname(os.path.abspath("__file__"))
config_path = os.path.join(root_dir, "datasets", "v1", "data.yaml")
print(config_path)
# Out:
# d:\Programming\Work\sewerbot_ai\yolo\own\datasets\v1\data.yaml

# %%
# Use the model
results = model.train(data=config_path, epochs=25)  # train the model
# Out:
# Ultralytics YOLOv8.0.201  Python-3.10.7 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
results = model.val()  # evaluate model performance on the validation set
# Out:
# Ultralytics YOLOv8.0.201  Python-3.10.7 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\Programming\Work\sewerbot_ai\yolo\own\datasets\v1\valid\labels.cache... 33 images, 15 backgrounds, 0 corrupt: 100%|██████████| 33/33 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:02<00:00,  1.08it/s]
#                    all         33         18      0.997          1      0.995      0.995
# Speed: 0.9ms preprocess, 9.1ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs\detect\train72

# %%
# automatically saves it as best.pt
# results = model.export(format="-")

# %%
results
# Out:
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x000002C7CD19AB00>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
# ...

# %%
results = model('D:\\Programming\\Work\\sewerbot_ai\\resnet\\src\\pictures\\temp\\test_medium\\test_medium_2109.jpg')  # predict on an image
# Out:
# image 1/1 D:\Programming\Work\sewerbot_ai\resnet\src\pictures\temp\test_medium\test_medium_2157.jpg: 480x640 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
results[0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))

# %%
from PIL import Image
img = Image.open('D:\\Programming\\Work\\sewerbot_ai\\resnet\\src\\pictures\\temp\\test_medium\\test_medium_2157.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
gray_image = img.convert('L')
gray_image
# Out:
# <PIL.Image.Image image mode=L size=640x480>

# %%
results = model(img)  # predict on an image
results[0].boxes.xyxy
# Out:
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# torch.Tensor

# %%
import cv2

# Load the image
image = cv2.imread('D:\\Programming\\Work\\sewerbot_ai\\resnet\\src\\pictures\\temp\\test_medium\\test_medium_2157.jpg')

# Convert to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[152, 151, 150, ..., 107, 107, 107],
#        [151, 151, 150, ..., 107, 107, 108],
#        [150, 150, 150, ..., 107, 108, 108],
#        ...,
#        [175, 177, 179, ..., 117, 117, 117],
#        [175, 177, 179, ..., 117, 117, 116],
#        [175, 177, 179, ..., 117, 117, 116]], dtype=uint8)

# %%
results = model(img)  # predict on an image
results[0].boxes.cls
# Out:
# 0: 480x640 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([], device='cuda:0')

# %%
if results[0].boxes.xyxy.numel() == 0:
    print("Tensor 1 is empty")
else:
    print("Tensor 1 is not empty")
# Out:
# Tensor 1 is empty

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

# %%
transform = transforms.Compose([
    transforms.Resize((640, 640)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
cap = cv2.VideoCapture("C:\\_TBZ mindenes\\sewerbot_ai\\src\\test_videos\\test_medium.avi")
# cap = cv2.VideoCapture("http://192.168.1.1:8081/")
class_labels = ['end', 'notEnd']

while True:
    ret, frame_og = cap.read()

    if not ret:
        break

    frame = cv2.cvtColor(frame_og, cv2.COLOR_BGR2GRAY)
    frame = cv2.resize(frame, (640, 640))
    # frame = transform(Image.fromarray(frame))

    with torch.no_grad():
        output = model(frame)

    _, predicted_class = torch.max(output, 1)
    predicted_label = class_labels[predicted_class.item()]

    frame = cv2.cvtColor(frame.permute(1, 2, 0).numpy(), cv2.COLOR_RGB2BGR)  # Convert back to BGR
    cv2.putText(frame_og, f"Prediction: {predicted_label}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.imshow("IP Camera Stream", frame_og)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
os.system('yolo task=detect mode=predict model=D:\\Programming\\Work\\sewerbot_ai\\yolo\\own\\runs\\detect\\train7\\weights\\best.pt conf=0.25 source=D:\\Programming\\Work\\sewerbot_ai\\resnet\\src\\test_videos\\test_medium.avi')
# Out:
# 0
