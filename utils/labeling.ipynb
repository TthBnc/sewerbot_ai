# %%
from utils import slice_video, delete_temp_contents, process_video

import cv2
import os

# %%
root = os.path.dirname(os.path.abspath("__file__"))
print(root)
# Out:
# d:\Programming\Work\sewerbot_ai\utils

# %%
# src = 'C:\\_TBZ mindenes\\sewerbot_ai\\src\\videos'
# dest_dir = 'C:\\_TBZ mindenes\\sewerbot_ai\\src\\pictures'

src = os.path.join(root, "..", "src", "videos")
dest_dir = os.path.join(root, "..", "src", "pictures")

# %%
delete_temp_contents(os.path.join(dest_dir, "temp"))
# Out:
# Error deleting contents in d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\temp: [WinError 145] The directory is not empty: 'd:\\Programming\\Work\\sewerbot_ai\\utils\\..\\src\\pictures\\temp\\long_1'

# %%
video_files = [f for f in os.listdir(src) if f.endswith('.avi')]
write_path = os.path.join(dest_dir, "temp")
print(video_files)

for video_name_ext in video_files:
    slice_video(video_name_ext, 1, src, write_path=write_path)
# Out:
# ['long_1.avi', 'long_2.avi', 'medium_1.avi', 'medium_2.avi', 'medium_3.avi', 'short_1.avi', 'short_2.avi']
# d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\temp\long_1\long_1_1.jpg
# d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\temp\long_1\long_1_2.jpg
# d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\temp\long_1\long_1_3.jpg
# d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\temp\long_1\long_1_4.jpg
# d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\temp\long_1\long_1_5.jpg
# d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\temp\long_1\long_1_6.jpg
# d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\temp\long_1\long_1_7.jpg
# d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\temp\long_1\long_1_8.jpg
# d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\temp\long_1\long_1_9.jpg
# d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\temp\long_1\long_1_10.jpg
# ...

# %%
delete_temp_contents('C:\\_TBZ mindenes\\sewerbot_ai\\src\\pictures\\data\\end')
delete_temp_contents('C:\\_TBZ mindenes\\sewerbot_ai\\src\\pictures\\data\\notEnd')
# Out:
# Filed deleted: 0
# Folders deleted: 0
# Contents in C:\_TBZ mindenes\sewerbot_ai\src\pictures\data\end have been deleted.
# Filed deleted: 2788
# Folders deleted: 0
# Contents in C:\_TBZ mindenes\sewerbot_ai\src\pictures\data\notEnd have been deleted.

# %%
base_write_path = os.path.join(dest_dir, "data")
print(base_write_path)
# Out:
# d:\Programming\Work\sewerbot_ai\utils\..\src\pictures\data

# %% [markdown]
# # long_1

# %%
end_frames=[(1378, 2124)]
process_video('long_1.avi', special_frames=end_frames, src=src, base_write_path=base_write_path)
# Out:
# end of the video

# %% [markdown]
# # long_2

# %%
end_frames=[(1, 179), (1216, 1878), (3185, 3628), (3939, 4342)]
process_video('long_2.avi', special_frames=end_frames, src=src, base_write_path=base_write_path)
# Out:
# end of the video

# %% [markdown]
# # medium_1

# %%
end_frames=[(2151, 2901)]
process_video('medium_1.avi', special_frames=end_frames, src=src, base_write_path=base_write_path)
# Out:
# end of the video

# %% [markdown]
# # medium_2

# %%
end_frames=[(3342, 4156), (4282, 4364)]
process_video('medium_2.avi', special_frames=end_frames, src=src, base_write_path=base_write_path)
# Out:
# end of the video

# %% [markdown]
# # medium_3

# %%
end_frames=[(1, 903), (1064, 1606)]
process_video('medium_3.avi', special_frames=end_frames, src=src, base_write_path=base_write_path)
# Out:
# end of the video

# %% [markdown]
# # short_1

# %%
end_frames=[(1262, 2515)]
process_video('short_1.avi', special_frames=end_frames, src=src, base_write_path=base_write_path)
# Out:
# end of the video

# %% [markdown]
# # short_2

# %%
end_frames=[(440, 1488), (1938, 2800)]
process_video('short_2.avi', special_frames=end_frames, src=src, base_write_path=base_write_path)
# Out:
# end of the video
